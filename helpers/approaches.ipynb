# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
score = np.array([0.14079024150571795,0.13788165017198523,0.13893744951403778,0.1256119557156252,0.11997511918438342,0.1241506530803208])

# %%
plt.figure()
plt.plot(score,'o-')
plt.ylabel('Score',fontsize=16)
ax = plt.gca()
ax.set_xlim([-0.5,6.3])
ax.set_xticks([i for i in range(6)])
ax.set_xticklabels(['Random Forecast', 'Gradient boosted tree regression', 'Gradient Boosting regression', 'Extra trees regression','Stacking 4 best model','Stacking more models'],fontsize=12)
plt.grid()
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Random Forecast'),
#   Text(1, 0, 'Gradient boosted tree regression'),
#   Text(2, 0, 'Gradient Boosting regression'),
#   Text(3, 0, 'Extra trees regression'),
#   Text(4, 0, 'Stacking 4 best model'),
#   Text(5, 0, 'Stacking more models')])
